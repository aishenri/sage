# %%
#%matplotlib inline
# %display latex
plot(sqrt(-x^2+2*abs(x))*sgn(-x),[x,-2,2] ,
     figsize=4,xmin=-2,  xmax=2,
     ymin=-2, ymax=2, aspect_ratio=1,
     axes=False,fill=-sqrt(4-x^2), 
     color="black", fillcolor="black", 
     fillalpha=1) +plot(sqrt(-x^2+2*abs(x))*sgn(-x),
                        [x,-2,2], figsize=3,xmin=-2, 
                        xmax=2, ymin=-2, ymax=2,
                        aspect_ratio=1, axes=False,
                        fill=sqrt(4-x^2), 
                        color="red", fillcolor="red",
                        fillalpha=1)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
plot(sqrt(-x^2+2*abs(x))*sgn(-x),
     [x,-2,2],aspect_ratio=1,
     figsize=3,fontsize=5,fill=True)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
integrate(sqrt(-x^2+2*abs(x)),-2,2)
# Out:
# /home/pi/sage/local/lib/python2.7/site-packages/sage/symbolic/integration/integral.py:790: DeprecationWarning: Variable of integration should be specified explicitly.
# See http://trac.sagemath.org/12438 for details.
#   expression, v, a, b = _normalize_integral_input(expression, v, a, b)
# pi

# %%
def f(x):
    if x<0:
        return sqrt(-x^2-2*x)
    else:
        return -sqrt(-x^2+2*x)
a=plot(f,(x,-2,2),color='white',
       fill=sqrt(4-x^2),fillcolor="black",alpha=0.1)
b=plot(f,(x,-2,2),color='white',
       fill=-sqrt(4-x^2),fillcolor="white",alpha=0.1)
p = circle((0,0),2,color="red",zorder=-5)
show(a+p,figsize=2,axes=False,aspect_ratio=1)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
p4 = circle((0,0),2,color="red",zorder=-5)
p5= circle((0,0),0.33,color="red",zorder=-5)
p6= circle((0,0),0.66,color="red",zorder=-5)
p7= circle((0,0),0.99,color="red",zorder=-5)
p8= circle((0,0),1.32,color="red",zorder=-5)
p9= circle((0,0),1.66,color="red",zorder=-5)
d=plot(f,(x,-2,2),color='white',
       fill=sqrt(4-x^2),fillcolor="lightgrey",alpha=0.1);
p=plot(x,-2,2,color="white",
       fill=x,fillcolor="green");
#o=plot(-x,-2,2,color="white");
r=plot(-(x*1/8),-2,2,color="yellow");
t=plot(x*1/4,-2,2,color="green");
l=plot(x*1/2,-2,2,color="red");
u=plot(x,-2,2,color="green");
v=plot(-x,-2,2,color="violet");
q=plot(f,(x,-2,2),color='white',
       fill=-sqrt(4-x^2),fillcolor="red",alpha=0.1)
# p3 = arrow((0,0),(2*cos(pi/6),2*sin(pi/6)),
       #    linestyle="dashed", color="red")
a2 = arrow((0,0), (2*cos(pi/8),-sin(2*pi/8)), color="blue",
          linestyle="dashed",thickness=2)
a3 = arrow((0,0), (3*cos(pi/4.8+pi/2),3*sin(2*pi/4.8+pi/2)),
          color="blue", linestyle="dashed",thickness=2)
show(a+b+u+p4+a3+a2+p5+p6+p7+p8+p9,
     figsize=4,axes=True,aspect_ratio=1,
     gridlines="Minor",frame=True,fontsize=6)
# Out:
# Graphics object consisting of 13 graphics primitives

# %%
p1 = point(((0,2),(2,0)), color="red", 
pointsize=30)
p2 = line(((0,2),(2,0)), color="black", 
thickness=1)
p1 + p2
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
d=plot(f,(x,-2,2),color='white',
       fill=sqrt(4-x^2),fillcolor="black");
p=plot(x,-2,2,color="white",
       fill=x,fillcolor="green");
#o=plot(-x,-2,2,color="white");
r=plot(-(x*1/8),-2,2,color="yellow");
t=plot(x*1/4,-2,2,color="green");
l=plot(x*1/2,-2,2,color="red");
u=plot(x,-2,2,color="green");
v=plot(-x,-2,2,color="violet");
q=plot(f,(x,-2,2),color='white',
       fill=-sqrt(4-x^2),fillcolor="red",alpha=0.1)
l1= point(((0,0),(2,0)), color="red", 
pointsize=30)
l2 = line(((0,0),(2,0)), color="black", 
thickness=1)
l3= point(((0,0),(2,0)), color="red", 
pointsize=30)
l4 = line(((0,0),(2,0)), color="black", 
thickness=1)
show(a+b+u+v+l1+l2,figsize=4,
     axes=False,aspect_ratio=1,
     frame=True,fontsize=6)
# Out:
# Graphics object consisting of 8 graphics primitives

# %%
yi=1/(365.24/360)

# %%
ya=3.14*3.14

# %%
1/ya-yi
# Out:
# -0.884229276223591

# %%
n(20/6)
# Out:
# 3.33333333333333

# %%
365.25/5
# Out:
# 73.0500000000000

# %%
360/5.0
# Out:
# 72.0000000000000

# %%
365.25*4
# Out:
# 1461.00000000000

# %%
sqrt(1461.0)
# Out:
# 38.2230297072328

# %%
365.25/6.0
# Out:
# 60.8750000000000
