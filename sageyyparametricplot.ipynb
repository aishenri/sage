# %%
nt = 12;
np = 3*nt;
nr = 5;
radMax = 1.0;
radMin = 0.6;
thtMin = pi/4;
thtMax = pi/4;
phiMin = -3*pi/4;
phiMax = 3 *pi/4;
dr = (radMax - radMin)/(nr - 1);
Theta = pi/2/nt;
Phi = 3*pi/2/np;
#def f(switch):
  #if switch=="yin":
    #coords = 
  #else:
  #return (surfaceRad,)

# %%
T = SphericalElevation('radius', 
                       ['azimuth', 'elevation'])
nr, theta, phi = var('nr theta phi')
T.transform(radius=nr, azimuth=theta, elevation=phi)
(nr*cos(phi)*cos(theta), 
 nr*cos(phi)*sin(theta), nr*sin(phi))
plot3d(phi * theta, (theta, 0, pi),
       (phi, 0, 1), transformation=T)
# Out:
# Graphics3d Object
