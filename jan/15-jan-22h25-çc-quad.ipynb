# %%
from sage.plot.polygon import Polygon
r=2/n(pi);x=x;y=plot(x,x,0,1,color="yellow")
po1=point([1,1],color="brown");po2=point([0.8,0.8],color="red")
po3=point([0.6,0.6],color="green");po4=point([0.4,0.4],
color="black");po5=point([0.2,0.2],color="blue");
ci=circle((0,0),1.128,color="red",fill=True,alpha=0.2,)
po=polygon2d(((-1,1),(1,1),(1,-1),(-1,-1)),color="limegreen",
alpha=0.2,edgecolor="black",thickness=1,frame=True,axes=True)
show(po+ci+y+po1+po2+po3+po4+po5,figsize=5,fontsize=4)
# Out:
# Graphics object consisting of 8 graphics primitives

# %% [markdown]
# quadrature du cercle avec r=$\frac{2}{\sqrt \pi}$=1.12837916709551 (ma version)

# %%
r=2/sqrt(n(pi));r
# Out:
# 1.12837916709551

# %%
ce=circle((0,0),(1/1.1),color="cyan",fill=True,alpha=0.2,)
op=polygon2d(((-0.8,0.8),(0.8,0.8),(0.8,-0.8),(-0.8,-0.8)),
edgecolor="black",color="green",alpha=0.2)
show(op+ce+y+po1+po2+po3+po4+po5,figsize=5,fontsize=6,
gridlines=False,frame=true)
# Out:
# Graphics object consisting of 8 graphics primitives

# %% [markdown]
# Euler version $r_e=\frac{\sqrt\pi}{2}$ inverse de ma version.

# %%
µ=sqrt(n(pi)/2);µ
# Out:
# 1.25331413731550

# %%
ù=n(pi)*0.4;ù
# Out:
# 1.25663706143592

# %%
µ*ù
# Out:
# 1.57496099457224

# %%
3.141592653/2
# Out:
# 1.57079632650000

# %%
c=circle((0,0),0.282)
show(po+ci+op+ce+y+po1+po2+po3+po4+po5,figsize=10,fontsize=6,
gridlines="minor",frame=true)
# Out:
# Graphics object consisting of 10 graphics primitives

# %%
sqrt(2.0)*2
# Out:
# 2.82842712474619

# %%
sqrt(2.0)*3
# Out:
# 4.24264068711929

# %%
sqrt(2.0)*4
# Out:
# 5.65685424949238

# %%
sqrt(2.0)*5
# Out:
# 7.07106781186548

# %%
sqrt(2.0)*6
# Out:
# 8.48528137423857

# %%
sqrt(2.0)*7
# Out:
# 9.89949493661167

# %%
sqrt(2.0)*8
# Out:
# 11.3137084989848

# %%
sqrt(2.0)*9
# Out:
# 12.7279220613579

# %%
çc=n(pi)*1E+8/299792458;çc
# Out:
# 1.04792251097584

# %%
deg(x)=x*180/n(pi);deg(çc)
# Out:
# 60.0415371356674
