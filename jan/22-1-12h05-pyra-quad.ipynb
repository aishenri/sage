# %% [markdown]
# ç=314159265.3

# %%
L=1/n(pi)*360E-8;C=1/(n(pi)*360E+8)
ç=1/sqrt(L*C);round(ç,8)
# Out:
# 314159265.35897934

# %%
cr=n(pi)/6;r=sqrt(2.0) # coudée royale
cc=439.995154 #base 440
lg=cr*r*n(pi)*439.995154;lg # cercle circonscrit en MHz
pg=cr*cc*n(pi);c=lg-pg;c #Mhz
# Out:
# 299.792458025667

# %%
a=360E-8;b=360E+8;L=1/n(pi)*a;C=1/(n(pi)*b);ç=1/sqrt(L*C)
show(LatexExpr(r"\large \mu=L=\frac{1}{\pi a}="),L)
show(LatexExpr(r"\large \epsilon=C=\frac{1}{\pi b}="),C)
show(LatexExpr(r"\large ç=\frac{1}{\sqrt L C}="),round(ç,8))
show(LatexExpr(r"\large c=\frac{1}{\sqrt \mu \epsilon}="),
     round(c*1000000,9))
# Out:
# \large \mu=L=\frac{1}{\pi a}= 1.14591559026165e-6
# \large \epsilon=C=\frac{1}{\pi b}= 8.84194128288307e-12
# \large ç=\frac{1}{\sqrt L C}= 314159265.35897934
# \large c=\frac{1}{\sqrt \mu \epsilon}= 299792458.02566683

# %%
p=polygon([(-0.5,0.5),(-0.5,-0.5),(-0.5,-0.5),
(0.5,-0.5),(0.5,0.5),(0.5,0.5)],
 color="black",fill=False)
ri=circle((0,0),(sqrt(2.0)/2)*2,color="red")
rc=circle((0,0),1,color="blue")
show(rc+ri+p,gridlines="minor",figsize=3,fontsize=4,
gridlinesstyle=dict(color="lightgreen",alpha=0.3,
linestyle="-"),frame=False,axes=False)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
from sage.plot.plot import graphics_array
r=2/sqrt(n(pi));r
p3=plot(circle((0,0),r,color="red",fill=True,alpha=0.2,)+\
polygon(((-1,1),(1,1),(1,-1),(-1,-1)),color="blue",alpha=0.2,
        thickness=1,frame=True,axes=True));
p2= circle((0,0),r,color="red",
        fill=True,alpha=0.2,fontsize=6)  
p4=polygon(((-1,1),(1,1),(1,-1),(-1,-1)),color="blue",alpha=0.2,
       thickness=1,frame=True,axes=True)
p5=rc+ri+p3;p1=p4+p5;c=circle((0,0),0.282)
g = graphics_array([p1,p2,p3]);
g.show(frame=False,figsize=10,gridlines="minor",gridlinesstyle=dict(color="cyan",
linestyle="-",alpha=0.7))
# Out:
# Graphics Array of size 1 x 3

# %%
sqrt(2.0)/r
# Out:
# 1.25331413731550

# %%
sqrt(2.0)*r
# Out:
# 1.59576912160573

# %%
from sage.plot.polygon import Polygon
r=2/n(pi);x=x;y=plot(x,x,0,1,color="yellow")
po1=point([1,1],color="brown");po2=point([0.8,0.8],color="red")
po3=point([0.6,0.6],color="green");po4=point([0.4,0.4],
color="black");po5=point([0.2,0.2],color="blue");
ci=circle((0,0),1.128,color="red",fill=True,alpha=0.2,)
po=polygon2d(((-1,1),(1,1),(1,-1),(-1,-1)),color="limegreen",
alpha=0.2,edgecolor="black",thickness=1,frame=True,axes=True)
show(po+ci+y+po1+po2+po3+po4+po5,figsize=5,fontsize=4)
# Out:
# Graphics object consisting of 8 graphics primitives

# %%
op=polygon2d(((-0.8,0.8),(0.8,0.8),(0.8,-0.8),(-0.8,-0.8)),
edgecolor="black",color="green",alpha=0.2)
c=circle((0,0),0.282);ce=circle((0,0),(1/1.1),color="cyan",fill=True,alpha=0.2,)
show(po+ci+op+ce+y+po1+po2+po3+po4+po5,figsize=10,fontsize=6,
gridlines="minor",frame=true)
# Out:
# Graphics object consisting of 10 graphics primitives

# %%
show(po+ci+op+ce+y+po1+po2+po3+po4+po5,figsize=10,fontsize=6,
gridlines="minor",frame=true)
p1=po+ci+op+ce+y+po1+po2+po3+po4+po5
# Out:
# Graphics object consisting of 10 graphics primitives

# %%
g = graphics_array([p1,p2,p3]);
g.show(frame=False,figsize=10,gridlines="minor",
gridlinesstyle=dict(color="lightgray",linestyle="-"))
# Out:
# Graphics Array of size 1 x 3

# %% [markdown]
# Les 2 quadratures sont réprésentées sur la première figure :
# 1) r=1.128 et 2) r=0.8

# %%
r1=2/sqrt(n(pi));
r2=sqrt(n(pi))/2;r1,r2
# Out:
# (1.12837916709551, 0.886226925452758)

# %% [markdown]
# Il existe ainsi non pas une seule quadrature, mais 2 quadratures :

# %%
r1*r2
# Out:
# 1.00000000000000

# %%
(r1/r2)*3
# Out:
# 3.81971863420549

# %%
# %display latex
var("m c h v nu lambda_0 r n")
# Out:
# (m, c, h, v, nu, lambda_0, r, n)

# %%
m*v^2==h*nu
# Out:
# m*v^2 == h*nu

# %%
l=h/(m*v);l
# Out:
# h/(m*v)

# %%
2*pi*r==n*lambda_0
# Out:
# 2*pi*r == lambda_0*n

# %%
n*lambda_0==n*(h/(m*v))
# Out:
# lambda_0*n == h*n/(m*v)

# %%
m*v*r==n*(h/(2* pi))
# Out:
# m*r*v == 1/2*h*n/pi

# %%
var("m c h v nu lambda_0 r n a hb")
# Out:
# (m, c, h, v, nu, lambda_0, r, n, a, hb)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
0.53*2*2   # tâche d'airy 2.44 milieu=1.029
# Out:
# 2.12000000000000

# %%
-27.2*2
# Out:
# -54.4000000000000

# %%
-27.2/2
# Out:
# -13.6000000000000

# %%
m*v*a==h/(2*pi)
# Out:
# a*m*v == 1/2*h/pi

# %%
lambda_0==h/(m*v)
# Out:
# h*nu/m == h/(m*v)

# %%
h/(m*v)==2*pi*a
# Out:
# h/(m*v) == 2*pi*a

# %%
hb=h/(2*pi);hb==h/(m*v)
# Out:
# 1/2*h/pi == h/(m*v)

# %%
a=0.52918 # angstrom rayon de bohr 1 bohr

# %%
c=circle((0,0),0.282)
show(po+ci+op+ce+y+po1+po2+po3+po4+po5,figsize=10,fontsize=6,
gridlines="minor",frame=true)
# Out:
# Graphics object consisting of 10 graphics primitives

# %%
1.33*5,1.0294*5 #n*D
# Out:
# (6.65000000000000, 5.14700000000000)

# %% [markdown]
# n=c/v (v est la fréquence ?)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from IPython.display import Image
Image(filename="brachi.gif")
