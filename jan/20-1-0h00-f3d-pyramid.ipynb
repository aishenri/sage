# %%
# %run f3d.ipynb

# %%
p1=polygon([[1, 1, -1],[-1, 1, -1], [0, 0, 1]],color="blue",opacity=0.5)
p3=polygon([[1,-1, -1],[-1, -1, -1],[0, 0, 1]],color="green",opacity=0.5)
p2=polygon([[-1,-1, -1],[-1, 1, -1], [0, 0, 1]],color="red",opacity=0.5)
p4=polygon([[1,-1, -1],[1, 1, -1],[0, 0, 1]],color="yellow",opacity=0.5)
f3d(p1+p2+p3+p4)
# Out:
# Graphics3d Object

# %%
s=spherical_plot3d(1.7, (x, 0, 2*pi), (y, 0, pi),opacity=0.1,color="black")
f3d(s+p1+p2+p3+p4)
# Out:
# Graphics3d Object

# %%
cr=n(pi)/6;r=sqrt(2.0) # coudée royale
cc=439.995154 #base 440
gc=cr*r*n(pi)*439.995154
pc=cr*cc*n(pi);pc,gc
# Out:
# (723.763018062732, 1023.55547608840)

# %%
gc-pc
# Out:
# 299.792458025667

# %%
fc=461.080826557399 # base  pi 461  LA#466
cg=cr*r*n(pi)*fc;cg
cp=cr*n(pi)*fc;cg-cp
# Out:
# 314.159265358974

# %%
n(pi,digits=33)
# Out:
# 3.14159265358979323846264338327950

# %%
3.14159265358979323846264338327950/3.14159265358979
# Out:
# 1.00000000000000

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
466.16-440
# Out:
# 26.1600000000000

# %%
461.080826557399-439.995154    #la  - la
# Out:
# 21.0856725573990

# %%
461.080826557399/439.995154
# Out:
# 1.04792251088611

# %%
314159265.3/299792458
# Out:
# 1.04792251077911

# %%
9/8.0
# Out:
# 1.12500000000000

# %%
256/243.0
# Out:
# 1.05349794238683

# %%
h=6.626;hb=h/n(pi);hb/2
# Out:
# 1.05456065292690

# %%
1.05456065292690/1.05349794238683
# Out:
# 1.00100874477046
